# %% [markdown]
# # European Soccer Database
# <p>this is dataset overview which i will be used for this project.</p>
# <h5>Dataset URL --> https://www.kaggle.com/code/dimarudov/data-analysis-using-sql/input</h5>
# <h2>Data overview</h2>
# <br>
# <table align="left">
#     <th>Table</th><th>Total Rows</th><th>Total Columns</th>
#     <tr><td>Country</td><td>11</td><td>2</td></tr>
#     <tr><td>League</td><td>11</td><td>3</td></tr>
#     <tr><td>Match</td><td>25979</td><td>115</td></tr>
#     <tr><td>Player</td><td>11060</td><td>7</td></tr>
#     <tr><td>Player_Attributes</td><td>183978</td><td>42</td></tr>
#     <tr><td>Team</td><td>299</td><td>5</td></tr>
#     <tr><td>Team_Attributes</td><td>1458</td><td>25</td></tr>
# </table>

# %%
# !pip install ipython-sql
## used for to write a sql query in jupyter notebook

# %%
import numpy as np 
import pandas as pd 
import sqlite3
import matplotlib.pyplot as plt

# %% [markdown]
# ### first way to read this data

# %%
conn = sqlite3.connect('database.sqlite/database.sqlite')
cursor = conn.cursor()
query = "select * from country ;"
result  = cursor.execute(query)
country= result.fetchall()
country
# Out:
# [(1, 'Belgium'),
#  (1729, 'England'),
#  (4769, 'France'),
#  (7809, 'Germany'),
#  (10257, 'Italy'),
#  (13274, 'Netherlands'),
#  (15722, 'Poland'),
#  (17642, 'Portugal'),
#  (19694, 'Scotland'),
#  (21518, 'Spain'),
#  (24558, 'Switzerland')]

# %% [markdown]
# ## second way to read this data

# %%
database_path = 'database.sqlite/database.sqlite'

# %%
conn = sqlite3.connect(database_path)

# %%
tables = pd.read_sql("""SELECT *
                        FROM Team;""", conn)
tables
# Out:
#         id  team_api_id  team_fifa_api_id      team_long_name team_short_name
# 0        1         9987             673.0            KRC Genk             GEN
# 1        2         9993             675.0        Beerschot AC             BAC
# 2        3        10000           15005.0    SV Zulte-Waregem             ZUL
# 3        4         9994            2007.0    Sporting Lokeren             LOK
# 4        5         9984            1750.0   KSV Cercle Brugge             CEB
# ..     ...          ...               ...                 ...             ...
# 294  49479        10190             898.0       FC St. Gallen             GAL
# 295  49837        10191            1715.0             FC Thun             THU
# 296  50201         9777             324.0         Servette FC             SER
# 297  50204         7730            1862.0  FC Lausanne-Sports             LAU
# 298  51606         7896               NaN              Lugano             LUG
#
# [299 rows x 5 columns]

# %%
type(tables)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Third way to access database

# %%
# %load_ext sql   
# %sql sqlite:///database.sqlite/database.sqlite

# %%
# %%sql
# select * from Player limit 5;
# Out:
#  * sqlite:///database.sqlite/database.sqlite
# Done.
# [(1, 505942, 'Aaron Appindangoye', 218353, '1992-02-29 00:00:00', 182.88, 187),
#  (2, 155782, 'Aaron Cresswell', 189615, '1989-12-15 00:00:00', 170.18, 146),
#  (3, 162549, 'Aaron Doran', 186170, '1991-05-13 00:00:00', 170.18, 163),
#  (4, 30572, 'Aaron Galindo', 140161, '1982-05-08 00:00:00', 182.88, 198),
#  (5, 23780, 'Aaron Hughes', 17725, '1979-11-08 00:00:00', 182.88, 154)]

# %%
# %%sql
# select * from Player limit 5;
# Out:
#  * sqlite:///database.sqlite/database.sqlite
# Done.
# [(1, 1, 1, '2008/2009', 1, '2008-08-17 00:00:00', 492473, 9987, 9993, 1, 1, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 1.73, 3.4, 5, 1.75, 3.35, 4.2, 1.85, 3.2, 3.5, 1.8, 3.3, 3.75, None, None, None, 1.7, 3.3, 4.33, 1.9, 3.3, 4, 1.65, 3.4, 4.5, 1.78, 3.25, 4, 1.73, 3.4, 4.2),
# ...

# %%
# %%sql
# select * from Player limit 5;
# Out:
#  * sqlite:///database.sqlite/database.sqlite
# Done.
# [(1, 505942, 'Aaron Appindangoye', 218353, '1992-02-29 00:00:00', 182.88, 187),
#  (2, 155782, 'Aaron Cresswell', 189615, '1989-12-15 00:00:00', 170.18, 146),
#  (3, 162549, 'Aaron Doran', 186170, '1991-05-13 00:00:00', 170.18, 163),
#  (4, 30572, 'Aaron Galindo', 140161, '1982-05-08 00:00:00', 182.88, 198),
#  (5, 23780, 'Aaron Hughes', 17725, '1979-11-08 00:00:00', 182.88, 154)]
